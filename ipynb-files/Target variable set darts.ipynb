# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

def load_dataset(name):
    if name == "jurisdiction":
        df = pd.read_csv('./datasets/CA.csv')
        #df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
        #df.rename(columns={'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'item_id'}, inplace=True)
        #df.replace({'item_id': {'total_patients_hospitalized_covid_confirmed': 'y'}}, inplace=True)
        #data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
        #data.drop("variable", axis='columns', inplace=True)

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

def load_dataset(name):
    if name == "CA":
        df = pd.read_csv('./datasets/CA.csv')
        df = df[['collection_date','total_patients_hospitalized_covid_confirmed']]
        df.rename(columns={'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'item_id'}, inplace=True)
        data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
        data.drop("variable", axis='columns', inplace=True)

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

def load_dataset(name):
    if name == "CA":
        df = pd.read_csv('./datasets/imputation_cvd.csv')
        df = df[df['jurisdiction'] == 'CA']
        df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
        df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'target'}, axis='columns', inplace=True)
        df['item_id'] = 'y'

# %%
df
# Out:
#        timestamp  target item_id
# 1296  01-08-2020  5066.0       y
# 1297  02-08-2020  5549.0       y
# 1298  03-08-2020  6100.0       y
# 1299  04-08-2020  5657.0       y
# 1300  05-08-2020  5950.0       y
# ...          ...     ...     ...
# 2587  13-02-2024  1509.0       y
# 2588  14-02-2024  1479.0       y
# 2589  15-02-2024  1474.0       y
# 2590  16-02-2024  1508.0       y
# 2591  17-02-2024  1434.0       y
#
# [1296 rows x 3 columns]

# %%
data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
data.drop("variable", axis='columns', inplace=True)
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_18624\1949050325.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')

# %%
data
# Out:
#        timestamp item_id  target
# 0     01-08-2020       y  5066.0
# 1     02-08-2020       y  5549.0
# 2     03-08-2020       y  6100.0
# 3     04-08-2020       y  5657.0
# 4     05-08-2020       y  5950.0
# ...          ...     ...     ...
# 1291  13-02-2024       y  1509.0
# 1292  14-02-2024       y  1479.0
# 1293  15-02-2024       y  1474.0
# 1294  16-02-2024       y  1508.0
# 1295  17-02-2024       y  1434.0
#
# [1296 rows x 3 columns]

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

def load_dataset(name):
    if name == "CA":
        df = pd.read_csv('./datasets/imputation_cvd.csv')
        df = df[df['jurisdiction'] == 'CA']
        df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
        df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'target'}, axis='columns', inplace=True)
        df['item_id'] = 'y'
        data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
        data.drop("variable", axis='columns', inplace=True)

# %%
df = df[df['jurisdiction']  == 'CA']
df
# Out:
#      jurisdiction       state collection_date  \
# 1296           CA  California      01-08-2020
# 1297           CA  California      02-08-2020
# 1298           CA  California      03-08-2020
# 1299           CA  California      04-08-2020
# 1300           CA  California      05-08-2020
# ...           ...         ...             ...
# 2587           CA  California      13-02-2024
# 2588           CA  California      14-02-2024
# 2589           CA  California      15-02-2024
# 2590           CA  California      16-02-2024
# 2591           CA  California      17-02-2024
#
#       number_hospitals_reporting_today  total_hospitals  \
# 1296                             285.0            371.0
# 1297                             352.0            371.0
# 1298                             355.0            371.0
# 1299                             355.0            371.0
# 1300                             355.0            371.0
# ...                                ...              ...
# 2587                             340.0            371.0
# 2588                             338.0            371.0
# 2589                             335.0            371.0
# 2590                             334.0            371.0
# 2591                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 1296                           559.0                          156.0
# 1297                           654.0                          193.0
# 1298                           692.0                          215.0
# 1299                           676.0                          208.0
# 1300                           691.0                          224.0
# ...                              ...                            ...
# 2587                           295.0                          155.0
# 2588                           272.0                          140.0
# 2589                           271.0                          143.0
# 2590                           297.0                          159.0
# 2591                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 1296                             122.0                             218.0
# 1297                             137.0                             252.0
# 1298                             162.0                             256.0
# 1299                             171.0                             246.0
# 1300                             152.0                             244.0
# ...                                ...                               ...
# 2587                              41.0                              79.0
# 2588                              26.0                              72.0
# 2589                              24.0                              81.0
# 2590                              48.0                              59.0
# 2591                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 1296                             110.0  ...        -0.516062        -0.856551
# 1297                             125.0  ...        -0.530730        -0.847541
# 1298                             115.0  ...        -0.545240        -0.838280
# 1299                             114.0  ...        -0.559589        -0.828770
# 1300                             108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 2587                              31.0  ...         0.687053         0.726608
# 2588                              22.0  ...         0.699458         0.714673
# 2589                              25.0  ...         0.711657         0.702527
# 2590                              21.0  ...         0.723644         0.690173
# 2591                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 1296  -0.866025       -0.5          0.201299          0.979530
# 1297  -0.866025       -0.5          0.394356          0.918958
# 1298  -0.866025       -0.5          0.571268          0.820763
# 1299  -0.866025       -0.5          0.724793          0.688967
# 1300  -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 2587   0.866025        0.5          0.485302         -0.874347
# 2588   0.866025        0.5          0.299363         -0.954139
# 2589   0.866025        0.5          0.101168         -0.994869
# 2590   0.866025        0.5         -0.101168         -0.994869
# 2591   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 1296        -0.974928        -0.222521       2           1
# 1297        -0.781831         0.623490       2           1
# 1298         0.000000         1.000000       2           0
# 1299         0.781831         0.623490       2           0
# 1300         0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 2587         0.781831         0.623490       4           0
# 2588         0.974928        -0.222521       4           0
# 2589         0.433884        -0.900969       4           0
# 2590        -0.433884        -0.900969       4           0
# 2591        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
import pandas as pd


df = pd.read_csv('daily-climate.csv')
df
# Out:
#       Unnamed: 0        date   meantemp   humidity  wind_speed  meanpressure
# 0              0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1              1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2              2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3              3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4              4  2013-01-05   6.000000  86.833333    3.700000   1016.500000
# ...          ...         ...        ...        ...         ...           ...
# 1570        1571  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 1571        1572  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 1572        1573  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 1573        1574  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 1574        1575  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [1575 rows x 6 columns]

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

df = pd.read_csv('daily-climate.csv')
df.rename({'date': 'timestamp', 'meantemp': 'y'}, axis='columns', inplace=True)
df = df.drop("Unnamed: 0", axis='columns')
data = df.melt(id_vars=['timestamp'], value_name='target')
data.rename({'variable': 'item_id'}, axis='columns', inplace=True)

# %%
data
# Out:
#        timestamp       item_id       target
# 0     2013-01-01             y    10.000000
# 1     2013-01-02             y     7.400000
# 2     2013-01-03             y     7.166667
# 3     2013-01-04             y     8.666667
# 4     2013-01-05             y     6.000000
# ...          ...           ...          ...
# 6295  2017-04-20  meanpressure   998.625000
# 6296  2017-04-21  meanpressure   999.875000
# 6297  2017-04-22  meanpressure  1001.600000
# 6298  2017-04-23  meanpressure  1002.125000
# 6299  2017-04-24  meanpressure  1004.142857
#
# [6300 rows x 3 columns]

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

df = pd.read_csv('CA.csv')
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
data = df.melt(id_vars=['timestamp'], value_name='target')
data.rename({'variable':'item_id'}, axis='columns', inplace=True)

# %%
df
# Out:
#        timestamp       y
# 0     2020-08-01  5066.0
# 1     2020-08-02  5549.0
# 2     2020-08-03  6100.0
# 3     2020-08-04  5657.0
# 4     2020-08-05  5950.0
# ...          ...     ...
# 1291  2024-02-13  1509.0
# 1292  2024-02-14  1479.0
# 1293  2024-02-15  1474.0
# 1294  2024-02-16  1508.0
# 1295  2024-02-17  1434.0
#
# [1296 rows x 2 columns]

# %%
data
# Out:
#        timestamp item_id  target
# 0     2020-08-01       y  5066.0
# 1     2020-08-02       y  5549.0
# 2     2020-08-03       y  6100.0
# 3     2020-08-04       y  5657.0
# 4     2020-08-05       y  5950.0
# ...          ...     ...     ...
# 1291  2024-02-13       y  1509.0
# 1292  2024-02-14       y  1479.0
# 1293  2024-02-15       y  1474.0
# 1294  2024-02-16       y  1508.0
# 1295  2024-02-17       y  1434.0
#
# [1296 rows x 3 columns]

# %%
df = df.drop(columns=df.columns.difference(['collection_date', 'jurisdiction','total_patients_hospitalized_covid_confirmed']))
df
# Out:
#      jurisdiction collection_date  total_patients_hospitalized_covid_confirmed
# 0              CA      01-08-2020                                       5066.0
# 1              CA      02-08-2020                                       5549.0
# 2              CA      03-08-2020                                       6100.0
# 3              CA      04-08-2020                                       5657.0
# 4              CA      05-08-2020                                       5950.0
# ...           ...             ...                                          ...
# 1291           CA      13-02-2024                                       1509.0
# 1292           CA      14-02-2024                                       1479.0
# 1293           CA      15-02-2024                                       1474.0
# 1294           CA      16-02-2024                                       1508.0
# 1295           CA      17-02-2024                                       1434.0
#
# [1296 rows x 3 columns]

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

df = pd.read_csv('djia.csv')
df
# Out:
#              Date   Open   High    Low  Close    Volume  Name
# 0      2006-01-03  77.76  79.35  77.24  79.11   3117200   MMM
# 1      2006-01-04  79.49  79.49  78.25  78.71   2558000   MMM
# 2      2006-01-05  78.41  78.65  77.56  77.99   2529500   MMM
# 3      2006-01-06  78.64  78.90  77.64  78.63   2479500   MMM
# 4      2006-01-09  78.50  79.83  78.46  79.02   1845600   MMM
# ...           ...    ...    ...    ...    ...       ...   ...
# 93607  2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 93608  2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 93609  2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 93610  2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 93611  2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [93612 rows x 7 columns]

# %%
def load_dataset(name):
    if name == "MSFT":
        df = df.drop(["High", "Low", "Close", "Volume"], axis='columns')
        df.rename({'Date': 'timestamp', 'Name': 'item_id'}, axis='columns', inplace=True)
        df.replace({'item_id': {'MSFT': 'y'}}, inplace=True)
        data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
        data.drop("variable", axis='columns', inplace=True)

# %%
df.rename({'collection_date': 'timestamp', 'jurisdiction': 'item_id'}, axis='columns', inplace=True)

# %%
df.replace({'item_id': {'CA': 'y'}}, inplace=True)

# %%
df
# Out:
#      item_id   timestamp
# 0          y  01-08-2020
# 1          y  02-08-2020
# 2          y  03-08-2020
# 3          y  04-08-2020
# 4          y  05-08-2020
# ...      ...         ...
# 1291       y  13-02-2024
# 1292       y  14-02-2024
# 1293       y  15-02-2024
# 1294       y  16-02-2024
# 1295       y  17-02-2024
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, variable, target]
# Index: []

# %%
data.drop("variable", axis='columns', inplace=True)

# %%
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, target]
# Index: []

# %%
data = data.pivot(columns="item_id", index="timestamp", values="target")
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.read_csv('imputation_cvd.csv')
df
# Out:
#       jurisdiction    state collection_date  number_hospitals_reporting_today  \
# 0               AZ  Arizona      01-08-2020                              55.0
# 1               AZ  Arizona      02-08-2020                              76.0
# 2               AZ  Arizona      03-08-2020                              82.0
# 3               AZ  Arizona      04-08-2020                              81.0
# 4               AZ  Arizona      05-08-2020                              84.0
# ...            ...      ...             ...                               ...
# 83606           UT     Utah      13-02-2024                              50.0
# 83607           UT     Utah      14-02-2024                              49.0
# 83608           UT     Utah      15-02-2024                              49.0
# 83609           UT     Utah      16-02-2024                              49.0
# 83610           UT     Utah      17-02-2024                              49.0
#
#        total_hospitals  admissions_all_covid_confirmed  \
# 0                 95.0                            95.0
# 1                 95.0                           124.0
# 2                 95.0                           100.0
# 3                 95.0                           121.0
# 4                 95.0                           120.0
# ...                ...                             ...
# 83606             53.0                            18.0
# 83607             53.0                            22.0
# 83608             53.0                            17.0
# 83609             53.0                             9.0
# 83610             53.0                            13.0
#
#        admissions_70_covid_confirmed  admissions_30_49_covid_confirmed  \
# 0                               26.0                              16.0
# 1                               29.0                              24.0
# 2                               26.0                              21.0
# 3                               32.0                              23.0
# 4                               27.0                              28.0
# ...                              ...                               ...
# 83606                            8.0                               5.0
# 83607                           10.0                               1.0
# 83608                            8.0                               3.0
# 83609                            3.0                               2.0
# 83610                            6.0                               1.0
#
#        admissions_50_69_covid_confirmed  admissions_50_59_covid_confirmed  \
# 0                                  35.0                              16.0
# 1                                  34.0                              12.0
# 2                                  28.0                              14.0
# 3                                  32.0                              12.0
# 4                                  35.0                              14.0
# ...                                 ...                               ...
# 83606                               2.0                               0.0
# 83607                               6.0                               3.0
# 83608                               2.0                               1.0
# 83609                               2.0                               1.0
# 83610                               5.0                               2.0
#
#        ...  day_of_year_sin  day_of_year_cos  month_sin  month_cos  \
# 0      ...        -0.516062        -0.856551  -0.866025       -0.5
# 1      ...        -0.530730        -0.847541  -0.866025       -0.5
# 2      ...        -0.545240        -0.838280  -0.866025       -0.5
# 3      ...        -0.559589        -0.828770  -0.866025       -0.5
# 4      ...        -0.573772        -0.819015  -0.866025       -0.5
# ...    ...              ...              ...        ...        ...
# 83606  ...         0.687053         0.726608   0.866025        0.5
# 83607  ...         0.699458         0.714673   0.866025        0.5
# 83608  ...         0.711657         0.702527   0.866025        0.5
# 83609  ...         0.723644         0.690173   0.866025        0.5
# 83610  ...         0.735417         0.677615   0.866025        0.5
#
#        day_of_month_sin  day_of_month_cos  day_of_week_sin  day_of_week_cos  \
# 0              0.201299          0.979530        -0.974928        -0.222521
# 1              0.394356          0.918958        -0.781831         0.623490
# 2              0.571268          0.820763         0.000000         1.000000
# 3              0.724793          0.688967         0.781831         0.623490
# 4              0.848644          0.528964         0.974928        -0.222521
# ...                 ...               ...              ...              ...
# 83606          0.485302         -0.874347         0.781831         0.623490
# 83607          0.299363         -0.954139         0.974928        -0.222521
# 83608          0.101168         -0.994869         0.433884        -0.900969
# 83609         -0.101168         -0.994869        -0.433884        -0.900969
# 83610         -0.299363         -0.954139        -0.974928        -0.222521
#
#        season  is_weekend
# 0           2           1
# 1           2           1
# 2           2           0
# 3           2           0
# 4           2           0
# ...       ...         ...
# 83606       4           0
# 83607       4           0
# 83608       4           0
# 83609       4           0
# 83610       4           1
#
# [83611 rows x 119 columns]

# %%
df = df[df['jurisdiction'] == 'CA']
df
# Out:
#      jurisdiction       state collection_date  \
# 1296           CA  California      01-08-2020
# 1297           CA  California      02-08-2020
# 1298           CA  California      03-08-2020
# 1299           CA  California      04-08-2020
# 1300           CA  California      05-08-2020
# ...           ...         ...             ...
# 2587           CA  California      13-02-2024
# 2588           CA  California      14-02-2024
# 2589           CA  California      15-02-2024
# 2590           CA  California      16-02-2024
# 2591           CA  California      17-02-2024
#
#       number_hospitals_reporting_today  total_hospitals  \
# 1296                             285.0            371.0
# 1297                             352.0            371.0
# 1298                             355.0            371.0
# 1299                             355.0            371.0
# 1300                             355.0            371.0
# ...                                ...              ...
# 2587                             340.0            371.0
# 2588                             338.0            371.0
# 2589                             335.0            371.0
# 2590                             334.0            371.0
# 2591                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 1296                           559.0                          156.0
# 1297                           654.0                          193.0
# 1298                           692.0                          215.0
# 1299                           676.0                          208.0
# 1300                           691.0                          224.0
# ...                              ...                            ...
# 2587                           295.0                          155.0
# 2588                           272.0                          140.0
# 2589                           271.0                          143.0
# 2590                           297.0                          159.0
# 2591                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 1296                             122.0                             218.0
# 1297                             137.0                             252.0
# 1298                             162.0                             256.0
# 1299                             171.0                             246.0
# 1300                             152.0                             244.0
# ...                                ...                               ...
# 2587                              41.0                              79.0
# 2588                              26.0                              72.0
# 2589                              24.0                              81.0
# 2590                              48.0                              59.0
# 2591                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 1296                             110.0  ...        -0.516062        -0.856551
# 1297                             125.0  ...        -0.530730        -0.847541
# 1298                             115.0  ...        -0.545240        -0.838280
# 1299                             114.0  ...        -0.559589        -0.828770
# 1300                             108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 2587                              31.0  ...         0.687053         0.726608
# 2588                              22.0  ...         0.699458         0.714673
# 2589                              25.0  ...         0.711657         0.702527
# 2590                              21.0  ...         0.723644         0.690173
# 2591                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 1296  -0.866025       -0.5          0.201299          0.979530
# 1297  -0.866025       -0.5          0.394356          0.918958
# 1298  -0.866025       -0.5          0.571268          0.820763
# 1299  -0.866025       -0.5          0.724793          0.688967
# 1300  -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 2587   0.866025        0.5          0.485302         -0.874347
# 2588   0.866025        0.5          0.299363         -0.954139
# 2589   0.866025        0.5          0.101168         -0.994869
# 2590   0.866025        0.5         -0.101168         -0.994869
# 2591   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 1296        -0.974928        -0.222521       2           1
# 1297        -0.781831         0.623490       2           1
# 1298         0.000000         1.000000       2           0
# 1299         0.781831         0.623490       2           0
# 1300         0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 2587         0.781831         0.623490       4           0
# 2588         0.974928        -0.222521       4           0
# 2589         0.433884        -0.900969       4           0
# 2590        -0.433884        -0.900969       4           0
# 2591        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 1296      01-08-2020                                       5066.0
# 1297      02-08-2020                                       5549.0
# 1298      03-08-2020                                       6100.0
# 1299      04-08-2020                                       5657.0
# 1300      05-08-2020                                       5950.0
# ...              ...                                          ...
# 2587      13-02-2024                                       1509.0
# 2588      14-02-2024                                       1479.0
# 2589      15-02-2024                                       1474.0
# 2590      16-02-2024                                       1508.0
# 2591      17-02-2024                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1889777750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
#        timestamp       y
# 1296  01-08-2020  5066.0
# 1297  02-08-2020  5549.0
# 1298  03-08-2020  6100.0
# 1299  04-08-2020  5657.0
# 1300  05-08-2020  5950.0
# ...          ...     ...
# 2587  13-02-2024  1509.0
# 2588  14-02-2024  1479.0
# 2589  15-02-2024  1474.0
# 2590  16-02-2024  1508.0
# 2591  17-02-2024  1434.0
#
# [1296 rows x 2 columns]

# %%
df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         2020-08-01                                       5066.0
# 1         2020-08-02                                       5549.0
# 2         2020-08-03                                       6100.0
# 3         2020-08-04                                       5657.0
# 4         2020-08-05                                       5950.0
# ...              ...                                          ...
# 1291      2024-02-13                                       1509.0
# 1292      2024-02-14                                       1479.0
# 1293      2024-02-15                                       1474.0
# 1294      2024-02-16                                       1508.0
# 1295      2024-02-17                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1889777750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
#        timestamp  item_id
# 0     2020-08-01   5066.0
# 1     2020-08-02   5549.0
# 2     2020-08-03   6100.0
# 3     2020-08-04   5657.0
# 4     2020-08-05   5950.0
# ...          ...      ...
# 1291  2024-02-13   1509.0
# 1292  2024-02-14   1479.0
# 1293  2024-02-15   1474.0
# 1294  2024-02-16   1508.0
# 1295  2024-02-17   1434.0
#
# [1296 rows x 2 columns]

# %%
import pandas as pd

# Read CSV file and select specific columns
df = pd.read_csv('CA.csv', usecols=['collection_date', 'total_patients_hospitalized_covid_confirmed'])

# Display the DataFrame
print(df)
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         2020-08-01                                       5066.0
# 1         2020-08-02                                       5549.0
# 2         2020-08-03                                       6100.0
# 3         2020-08-04                                       5657.0
# 4         2020-08-05                                       5950.0
# ...              ...                                          ...
# 1291      2024-02-13                                       1509.0
# 1292      2024-02-14                                       1479.0
# 1293      2024-02-15                                       1474.0
# 1294      2024-02-16                                       1508.0
# 1295      2024-02-17                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.to_csv('CA.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('CA.csv')
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         2020-08-01                                       5066.0
# 1         2020-08-02                                       5549.0
# 2         2020-08-03                                       6100.0
# 3         2020-08-04                                       5657.0
# 4         2020-08-05                                       5950.0
# ...              ...                                          ...
# 1291      2024-02-13                                       1509.0
# 1292      2024-02-14                                       1479.0
# 1293      2024-02-15                                       1474.0
# 1294      2024-02-16                                       1508.0
# 1295      2024-02-17                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
df
# Out:
#        timestamp       y
# 0     2020-08-01  5066.0
# 1     2020-08-02  5549.0
# 2     2020-08-03  6100.0
# 3     2020-08-04  5657.0
# 4     2020-08-05  5950.0
# ...          ...     ...
# 1291  2024-02-13  1509.0
# 1292  2024-02-14  1479.0
# 1293  2024-02-15  1474.0
# 1294  2024-02-16  1508.0
# 1295  2024-02-17  1434.0
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp'], value_name='target')
data
# Out:
#        timestamp variable  target
# 0     2020-08-01        y  5066.0
# 1     2020-08-02        y  5549.0
# 2     2020-08-03        y  6100.0
# 3     2020-08-04        y  5657.0
# 4     2020-08-05        y  5950.0
# ...          ...      ...     ...
# 1291  2024-02-13        y  1509.0
# 1292  2024-02-14        y  1479.0
# 1293  2024-02-15        y  1474.0
# 1294  2024-02-16        y  1508.0
# 1295  2024-02-17        y  1434.0
#
# [1296 rows x 3 columns]

# %%
data.rename({'variable':'item_id'}, axis='columns', inplace=True)
data
# Out:
#        timestamp item_id  target
# 0     2020-08-01       y  5066.0
# 1     2020-08-02       y  5549.0
# 2     2020-08-03       y  6100.0
# 3     2020-08-04       y  5657.0
# 4     2020-08-05       y  5950.0
# ...          ...     ...     ...
# 1291  2024-02-13       y  1509.0
# 1292  2024-02-14       y  1479.0
# 1293  2024-02-15       y  1474.0
# 1294  2024-02-16       y  1508.0
# 1295  2024-02-17       y  1434.0
#
# [1296 rows x 3 columns]

# %%
data = data.pivot(columns="item_id", index="timestamp", values="target")

# %%
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data['y'] = data['y'].astype(float)
data = data.interpolate()

# %%
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data = data.pivot(columns="item_id", index="timestamp", values="target")
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data['y'] = data['y'].astype(float)
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data = data.interpolate()
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data.index = pd.to_datetime(data.index)
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         2020-08-01                                       5066.0
# 1         2020-08-02                                       5549.0
# 2         2020-08-03                                       6100.0
# 3         2020-08-04                                       5657.0
# 4         2020-08-05                                       5950.0
# ...              ...                                          ...
# 1291      2024-02-13                                       1509.0
# 1292      2024-02-14                                       1479.0
# 1293      2024-02-15                                       1474.0
# 1294      2024-02-16                                       1508.0
# 1295      2024-02-17                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'item_id'}, axis='columns', inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1823532576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'item_id'}, axis='columns', inplace=True)
#        timestamp  item_id
# 0     2020-08-01   5066.0
# 1     2020-08-02   5549.0
# 2     2020-08-03   6100.0
# 3     2020-08-04   5657.0
# 4     2020-08-05   5950.0
# ...          ...      ...
# 1291  2024-02-13   1509.0
# 1292  2024-02-14   1479.0
# 1293  2024-02-15   1474.0
# 1294  2024-02-16   1508.0
# 1295  2024-02-17   1434.0
#
# [1296 rows x 2 columns]

# %%
df.replace({'item_id': {'total_patients_hospitalized_covid_confirmed': 'y'}}, inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\3800135341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace({'item_id': {'total_patients_hospitalized_covid_confirmed': 'y'}}, inplace=True)
#        timestamp  item_id
# 0     2020-08-01   5066.0
# 1     2020-08-02   5549.0
# 2     2020-08-03   6100.0
# 3     2020-08-04   5657.0
# 4     2020-08-05   5950.0
# ...          ...      ...
# 1291  2024-02-13   1509.0
# 1292  2024-02-14   1479.0
# 1293  2024-02-15   1474.0
# 1294  2024-02-16   1508.0
# 1295  2024-02-17   1434.0
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp'], value_name='target')
data
# Out:
#        timestamp variable  target
# 0     2020-08-01  item_id  5066.0
# 1     2020-08-02  item_id  5549.0
# 2     2020-08-03  item_id  6100.0
# 3     2020-08-04  item_id  5657.0
# 4     2020-08-05  item_id  5950.0
# ...          ...      ...     ...
# 1291  2024-02-13  item_id  1509.0
# 1292  2024-02-14  item_id  1479.0
# 1293  2024-02-15  item_id  1474.0
# 1294  2024-02-16  item_id  1508.0
# 1295  2024-02-17  item_id  1434.0
#
# [1296 rows x 3 columns]

# %%
data.rename({'variable':'item_id'}, axis='columns', inplace=True)
data
# Out:
#        timestamp  item_id  target
# 0     2020-08-01  item_id  5066.0
# 1     2020-08-02  item_id  5549.0
# 2     2020-08-03  item_id  6100.0
# 3     2020-08-04  item_id  5657.0
# 4     2020-08-05  item_id  5950.0
# ...          ...      ...     ...
# 1291  2024-02-13  item_id  1509.0
# 1292  2024-02-14  item_id  1479.0
# 1293  2024-02-15  item_id  1474.0
# 1294  2024-02-16  item_id  1508.0
# 1295  2024-02-17  item_id  1434.0
#
# [1296 rows x 3 columns]

# %%
df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         2020-08-01                                       5066.0
# 1         2020-08-02                                       5549.0
# 2         2020-08-03                                       6100.0
# 3         2020-08-04                                       5657.0
# 4         2020-08-05                                       5950.0
# ...              ...                                          ...
# 1291      2024-02-13                                       1509.0
# 1292      2024-02-14                                       1479.0
# 1293      2024-02-15                                       1474.0
# 1294      2024-02-16                                       1508.0
# 1295      2024-02-17                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1889777750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
#        timestamp       y
# 0     2020-08-01  5066.0
# 1     2020-08-02  5549.0
# 2     2020-08-03  6100.0
# 3     2020-08-04  5657.0
# 4     2020-08-05  5950.0
# ...          ...     ...
# 1291  2024-02-13  1509.0
# 1292  2024-02-14  1479.0
# 1293  2024-02-15  1474.0
# 1294  2024-02-16  1508.0
# 1295  2024-02-17  1434.0
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp'], value_name='target')
data
# Out:
#        timestamp variable  target
# 0     2020-08-01        y  5066.0
# 1     2020-08-02        y  5549.0
# 2     2020-08-03        y  6100.0
# 3     2020-08-04        y  5657.0
# 4     2020-08-05        y  5950.0
# ...          ...      ...     ...
# 1291  2024-02-13        y  1509.0
# 1292  2024-02-14        y  1479.0
# 1293  2024-02-15        y  1474.0
# 1294  2024-02-16        y  1508.0
# 1295  2024-02-17        y  1434.0
#
# [1296 rows x 3 columns]

# %%
data.rename({'variable': 'item_id'}, axis='columns', inplace=True)
data
# Out:
#        timestamp item_id  target
# 0     2020-08-01       y  5066.0
# 1     2020-08-02       y  5549.0
# 2     2020-08-03       y  6100.0
# 3     2020-08-04       y  5657.0
# 4     2020-08-05       y  5950.0
# ...          ...     ...     ...
# 1291  2024-02-13       y  1509.0
# 1292  2024-02-14       y  1479.0
# 1293  2024-02-15       y  1474.0
# 1294  2024-02-16       y  1508.0
# 1295  2024-02-17       y  1434.0
#
# [1296 rows x 3 columns]

# %%
data = data.pivot(columns="item_id", index="timestamp", values="target")
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data['y'] = data['y'].astype(float)
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data = data.interpolate()
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data.index = pd.to_datetime(data.index)

# %%
data.index
# Out:
# DatetimeIndex(['2020-08-01', '2020-08-02', '2020-08-03', '2020-08-04',
#                '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-08',
#                '2020-08-09', '2020-08-10',
#                ...
#                '2024-02-08', '2024-02-09', '2024-02-10', '2024-02-11',
#                '2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-17'],
#               dtype='datetime64[ns]', name='timestamp', length=1296, freq=None)

# %%
import os, sys
sys.path.insert(1, os.path.join(sys.path[0], '../'))
import numpy as np
import pandas as pd
import pdb

def load_dataset(name):
    if name == "CA":
        df = pd.read_csv('CA.csv')
        df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
        df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
        data = df.melt(id_vars=['timestamp'], value_name='target')
        data.rename({'variable': 'item_id'}, axis='columns', inplace=True)
        data = data.pivot(columns="item_id", index="timestamp", values="target")
    data['y'] = data['y'].astype(float)
    data = data.interpolate()
    data.index = pd.to_datetime(data.index)
    return data

# %%
data
# Out:
# item_id          y
# timestamp
# 2020-08-01  5066.0
# 2020-08-02  5549.0
# 2020-08-03  6100.0
# 2020-08-04  5657.0
# 2020-08-05  5950.0
# ...            ...
# 2024-02-13  1509.0
# 2024-02-14  1479.0
# 2024-02-15  1474.0
# 2024-02-16  1508.0
# 2024-02-17  1434.0
#
# [1296 rows x 1 columns]

# %%
data['y']
# Out:
# timestamp
# 2020-08-01    5066.0
# 2020-08-02    5549.0
# 2020-08-03    6100.0
# 2020-08-04    5657.0
# 2020-08-05    5950.0
#                ...
# 2024-02-13    1509.0
# 2024-02-14    1479.0
# 2024-02-15    1474.0
# 2024-02-16    1508.0
# 2024-02-17    1434.0
# Name: y, Length: 1296, dtype: float64

# %%
# Convert collection_date to yyyy-mm-dd format
df['collection_date'] = pd.to_datetime(df['collection_date'], format='%Y-%m-%d')

# Display the DataFrame
print(df)
# Out:
#      jurisdiction       state collection_date  \
# 0              CA  California      2020-08-01
# 1              CA  California      2020-08-02
# 2              CA  California      2020-08-03
# 3              CA  California      2020-08-04
# 4              CA  California      2020-08-05
# ...           ...         ...             ...
# 1291           CA  California      2024-02-13
# 1292           CA  California      2024-02-14
# 1293           CA  California      2024-02-15
# 1294           CA  California      2024-02-16
# 1295           CA  California      2024-02-17
#
#       number_hospitals_reporting_today  total_hospitals  \
# 0                                285.0            371.0
# 1                                352.0            371.0
# 2                                355.0            371.0
# 3                                355.0            371.0
# 4                                355.0            371.0
# ...                                ...              ...
# 1291                             340.0            371.0
# 1292                             338.0            371.0
# 1293                             335.0            371.0
# 1294                             334.0            371.0
# 1295                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 0                              559.0                          156.0
# 1                              654.0                          193.0
# 2                              692.0                          215.0
# 3                              676.0                          208.0
# 4                              691.0                          224.0
# ...                              ...                            ...
# 1291                           295.0                          155.0
# 1292                           272.0                          140.0
# 1293                           271.0                          143.0
# 1294                           297.0                          159.0
# 1295                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 0                                122.0                             218.0
# 1                                137.0                             252.0
# 2                                162.0                             256.0
# 3                                171.0                             246.0
# 4                                152.0                             244.0
# ...                                ...                               ...
# 1291                              41.0                              79.0
# 1292                              26.0                              72.0
# 1293                              24.0                              81.0
# 1294                              48.0                              59.0
# 1295                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 0                                110.0  ...        -0.516062        -0.856551
# 1                                125.0  ...        -0.530730        -0.847541
# 2                                115.0  ...        -0.545240        -0.838280
# 3                                114.0  ...        -0.559589        -0.828770
# 4                                108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 1291                              31.0  ...         0.687053         0.726608
# 1292                              22.0  ...         0.699458         0.714673
# 1293                              25.0  ...         0.711657         0.702527
# 1294                              21.0  ...         0.723644         0.690173
# 1295                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 0     -0.866025       -0.5          0.201299          0.979530
# 1     -0.866025       -0.5          0.394356          0.918958
# 2     -0.866025       -0.5          0.571268          0.820763
# 3     -0.866025       -0.5          0.724793          0.688967
# 4     -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 1291   0.866025        0.5          0.485302         -0.874347
# 1292   0.866025        0.5          0.299363         -0.954139
# 1293   0.866025        0.5          0.101168         -0.994869
# 1294   0.866025        0.5         -0.101168         -0.994869
# 1295   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 0           -0.974928        -0.222521       2           1
# 1           -0.781831         0.623490       2           1
# 2            0.000000         1.000000       2           0
# 3            0.781831         0.623490       2           0
# 4            0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 1291         0.781831         0.623490       4           0
# 1292         0.974928        -0.222521       4           0
# 1293         0.433884        -0.900969       4           0
# 1294        -0.433884        -0.900969       4           0
# 1295        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
df
# Out:
#      jurisdiction       state collection_date  \
# 0              CA  California      2020-08-01
# 1              CA  California      2020-08-02
# 2              CA  California      2020-08-03
# 3              CA  California      2020-08-04
# 4              CA  California      2020-08-05
# ...           ...         ...             ...
# 1291           CA  California      2024-02-13
# 1292           CA  California      2024-02-14
# 1293           CA  California      2024-02-15
# 1294           CA  California      2024-02-16
# 1295           CA  California      2024-02-17
#
#       number_hospitals_reporting_today  total_hospitals  \
# 0                                285.0            371.0
# 1                                352.0            371.0
# 2                                355.0            371.0
# 3                                355.0            371.0
# 4                                355.0            371.0
# ...                                ...              ...
# 1291                             340.0            371.0
# 1292                             338.0            371.0
# 1293                             335.0            371.0
# 1294                             334.0            371.0
# 1295                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 0                              559.0                          156.0
# 1                              654.0                          193.0
# 2                              692.0                          215.0
# 3                              676.0                          208.0
# 4                              691.0                          224.0
# ...                              ...                            ...
# 1291                           295.0                          155.0
# 1292                           272.0                          140.0
# 1293                           271.0                          143.0
# 1294                           297.0                          159.0
# 1295                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 0                                122.0                             218.0
# 1                                137.0                             252.0
# 2                                162.0                             256.0
# 3                                171.0                             246.0
# 4                                152.0                             244.0
# ...                                ...                               ...
# 1291                              41.0                              79.0
# 1292                              26.0                              72.0
# 1293                              24.0                              81.0
# 1294                              48.0                              59.0
# 1295                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 0                                110.0  ...        -0.516062        -0.856551
# 1                                125.0  ...        -0.530730        -0.847541
# 2                                115.0  ...        -0.545240        -0.838280
# 3                                114.0  ...        -0.559589        -0.828770
# 4                                108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 1291                              31.0  ...         0.687053         0.726608
# 1292                              22.0  ...         0.699458         0.714673
# 1293                              25.0  ...         0.711657         0.702527
# 1294                              21.0  ...         0.723644         0.690173
# 1295                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 0     -0.866025       -0.5          0.201299          0.979530
# 1     -0.866025       -0.5          0.394356          0.918958
# 2     -0.866025       -0.5          0.571268          0.820763
# 3     -0.866025       -0.5          0.724793          0.688967
# 4     -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 1291   0.866025        0.5          0.485302         -0.874347
# 1292   0.866025        0.5          0.299363         -0.954139
# 1293   0.866025        0.5          0.101168         -0.994869
# 1294   0.866025        0.5         -0.101168         -0.994869
# 1295   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 0           -0.974928        -0.222521       2           1
# 1           -0.781831         0.623490       2           1
# 2            0.000000         1.000000       2           0
# 3            0.781831         0.623490       2           0
# 4            0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 1291         0.781831         0.623490       4           0
# 1292         0.974928        -0.222521       4           0
# 1293         0.433884        -0.900969       4           0
# 1294        -0.433884        -0.900969       4           0
# 1295        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
df.to_csv('CA.csv',index=False)

# %%
# Convert collection_date to yyyy-mm-dd format
df['collection_date'] = pd.to_datetime(df['collection_date'], format='%d-%m-%Y')

# Display the DataFrame
print(df)
# Out:
#      jurisdiction       state collection_date  \
# 0              CA  California      2020-08-01
# 1              CA  California      2020-08-02
# 2              CA  California      2020-08-03
# 3              CA  California      2020-08-04
# 4              CA  California      2020-08-05
# ...           ...         ...             ...
# 1291           CA  California      2024-02-13
# 1292           CA  California      2024-02-14
# 1293           CA  California      2024-02-15
# 1294           CA  California      2024-02-16
# 1295           CA  California      2024-02-17
#
#       number_hospitals_reporting_today  total_hospitals  \
# 0                                285.0            371.0
# 1                                352.0            371.0
# 2                                355.0            371.0
# 3                                355.0            371.0
# 4                                355.0            371.0
# ...                                ...              ...
# 1291                             340.0            371.0
# 1292                             338.0            371.0
# 1293                             335.0            371.0
# 1294                             334.0            371.0
# 1295                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 0                              559.0                          156.0
# 1                              654.0                          193.0
# 2                              692.0                          215.0
# 3                              676.0                          208.0
# 4                              691.0                          224.0
# ...                              ...                            ...
# 1291                           295.0                          155.0
# 1292                           272.0                          140.0
# 1293                           271.0                          143.0
# 1294                           297.0                          159.0
# 1295                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 0                                122.0                             218.0
# 1                                137.0                             252.0
# 2                                162.0                             256.0
# 3                                171.0                             246.0
# 4                                152.0                             244.0
# ...                                ...                               ...
# 1291                              41.0                              79.0
# 1292                              26.0                              72.0
# 1293                              24.0                              81.0
# 1294                              48.0                              59.0
# 1295                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 0                                110.0  ...        -0.516062        -0.856551
# 1                                125.0  ...        -0.530730        -0.847541
# 2                                115.0  ...        -0.545240        -0.838280
# 3                                114.0  ...        -0.559589        -0.828770
# 4                                108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 1291                              31.0  ...         0.687053         0.726608
# 1292                              22.0  ...         0.699458         0.714673
# 1293                              25.0  ...         0.711657         0.702527
# 1294                              21.0  ...         0.723644         0.690173
# 1295                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 0     -0.866025       -0.5          0.201299          0.979530
# 1     -0.866025       -0.5          0.394356          0.918958
# 2     -0.866025       -0.5          0.571268          0.820763
# 3     -0.866025       -0.5          0.724793          0.688967
# 4     -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 1291   0.866025        0.5          0.485302         -0.874347
# 1292   0.866025        0.5          0.299363         -0.954139
# 1293   0.866025        0.5          0.101168         -0.994869
# 1294   0.866025        0.5         -0.101168         -0.994869
# 1295   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 0           -0.974928        -0.222521       2           1
# 1           -0.781831         0.623490       2           1
# 2            0.000000         1.000000       2           0
# 3            0.781831         0.623490       2           0
# 4            0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 1291         0.781831         0.623490       4           0
# 1292         0.974928        -0.222521       4           0
# 1293         0.433884        -0.900969       4           0
# 1294        -0.433884        -0.900969       4           0
# 1295        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
df.to_csv('CA.csv',index=False)

# %%
# Convert collection_date to yyyy-mm-dd format
df['collection_date'] = pd.to_datetime(df['collection_date'], format='%d-%m-%Y')

# Display the DataFrame
print(df)
# Out:
#      jurisdiction       state collection_date  \
# 0              CA  California      2020-08-01
# 1              CA  California      2020-08-02
# 2              CA  California      2020-08-03
# 3              CA  California      2020-08-04
# 4              CA  California      2020-08-05
# ...           ...         ...             ...
# 1291           CA  California      2024-02-13
# 1292           CA  California      2024-02-14
# 1293           CA  California      2024-02-15
# 1294           CA  California      2024-02-16
# 1295           CA  California      2024-02-17
#
#       number_hospitals_reporting_today  total_hospitals  \
# 0                                285.0            371.0
# 1                                352.0            371.0
# 2                                355.0            371.0
# 3                                355.0            371.0
# 4                                355.0            371.0
# ...                                ...              ...
# 1291                             340.0            371.0
# 1292                             338.0            371.0
# 1293                             335.0            371.0
# 1294                             334.0            371.0
# 1295                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 0                              559.0                          156.0
# 1                              654.0                          193.0
# 2                              692.0                          215.0
# 3                              676.0                          208.0
# 4                              691.0                          224.0
# ...                              ...                            ...
# 1291                           295.0                          155.0
# 1292                           272.0                          140.0
# 1293                           271.0                          143.0
# 1294                           297.0                          159.0
# 1295                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 0                                122.0                             218.0
# 1                                137.0                             252.0
# 2                                162.0                             256.0
# 3                                171.0                             246.0
# 4                                152.0                             244.0
# ...                                ...                               ...
# 1291                              41.0                              79.0
# 1292                              26.0                              72.0
# 1293                              24.0                              81.0
# 1294                              48.0                              59.0
# 1295                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 0                                110.0  ...        -0.516062        -0.856551
# 1                                125.0  ...        -0.530730        -0.847541
# 2                                115.0  ...        -0.545240        -0.838280
# 3                                114.0  ...        -0.559589        -0.828770
# 4                                108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 1291                              31.0  ...         0.687053         0.726608
# 1292                              22.0  ...         0.699458         0.714673
# 1293                              25.0  ...         0.711657         0.702527
# 1294                              21.0  ...         0.723644         0.690173
# 1295                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 0     -0.866025       -0.5          0.201299          0.979530
# 1     -0.866025       -0.5          0.394356          0.918958
# 2     -0.866025       -0.5          0.571268          0.820763
# 3     -0.866025       -0.5          0.724793          0.688967
# 4     -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 1291   0.866025        0.5          0.485302         -0.874347
# 1292   0.866025        0.5          0.299363         -0.954139
# 1293   0.866025        0.5          0.101168         -0.994869
# 1294   0.866025        0.5         -0.101168         -0.994869
# 1295   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 0           -0.974928        -0.222521       2           1
# 1           -0.781831         0.623490       2           1
# 2            0.000000         1.000000       2           0
# 3            0.781831         0.623490       2           0
# 4            0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 1291         0.781831         0.623490       4           0
# 1292         0.974928        -0.222521       4           0
# 1293         0.433884        -0.900969       4           0
# 1294        -0.433884        -0.900969       4           0
# 1295        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         2020-08-01                                       5066.0
# 1         2020-08-02                                       5549.0
# 2         2020-08-03                                       6100.0
# 3         2020-08-04                                       5657.0
# 4         2020-08-05                                       5950.0
# ...              ...                                          ...
# 1291      2024-02-13                                       1509.0
# 1292      2024-02-14                                       1479.0
# 1293      2024-02-15                                       1474.0
# 1294      2024-02-16                                       1508.0
# 1295      2024-02-17                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1889777750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'y'}, axis='columns', inplace=True)
#       timestamp       y
# 0    2020-08-01  5066.0
# 1    2020-08-02  5549.0
# 2    2020-08-03  6100.0
# 3    2020-08-04  5657.0
# 4    2020-08-05  5950.0
# ...         ...     ...
# 1291 2024-02-13  1509.0
# 1292 2024-02-14  1479.0
# 1293 2024-02-15  1474.0
# 1294 2024-02-16  1508.0
# 1295 2024-02-17  1434.0
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp'], value_name='target')
data
# Out:
#       timestamp variable  target
# 0    2020-08-01        y  5066.0
# 1    2020-08-02        y  5549.0
# 2    2020-08-03        y  6100.0
# 3    2020-08-04        y  5657.0
# 4    2020-08-05        y  5950.0
# ...         ...      ...     ...
# 1291 2024-02-13        y  1509.0
# 1292 2024-02-14        y  1479.0
# 1293 2024-02-15        y  1474.0
# 1294 2024-02-16        y  1508.0
# 1295 2024-02-17        y  1434.0
#
# [1296 rows x 3 columns]

# %%
data.rename({'variable': 'item_id'}, axis='columns', inplace=True)
data
# Out:
#       timestamp item_id  target
# 0    2020-08-01       y  5066.0
# 1    2020-08-02       y  5549.0
# 2    2020-08-03       y  6100.0
# 3    2020-08-04       y  5657.0
# 4    2020-08-05       y  5950.0
# ...         ...     ...     ...
# 1291 2024-02-13       y  1509.0
# 1292 2024-02-14       y  1479.0
# 1293 2024-02-15       y  1474.0
# 1294 2024-02-16       y  1508.0
# 1295 2024-02-17       y  1434.0
#
# [1296 rows x 3 columns]

# %%
df = df[df['jurisdiction'] == 'CA']
df
# Out:
#      jurisdiction       state collection_date  \
# 1296           CA  California      01-08-2020
# 1297           CA  California      02-08-2020
# 1298           CA  California      03-08-2020
# 1299           CA  California      04-08-2020
# 1300           CA  California      05-08-2020
# ...           ...         ...             ...
# 2587           CA  California      13-02-2024
# 2588           CA  California      14-02-2024
# 2589           CA  California      15-02-2024
# 2590           CA  California      16-02-2024
# 2591           CA  California      17-02-2024
#
#       number_hospitals_reporting_today  total_hospitals  \
# 1296                             285.0            371.0
# 1297                             352.0            371.0
# 1298                             355.0            371.0
# 1299                             355.0            371.0
# 1300                             355.0            371.0
# ...                                ...              ...
# 2587                             340.0            371.0
# 2588                             338.0            371.0
# 2589                             335.0            371.0
# 2590                             334.0            371.0
# 2591                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 1296                           559.0                          156.0
# 1297                           654.0                          193.0
# 1298                           692.0                          215.0
# 1299                           676.0                          208.0
# 1300                           691.0                          224.0
# ...                              ...                            ...
# 2587                           295.0                          155.0
# 2588                           272.0                          140.0
# 2589                           271.0                          143.0
# 2590                           297.0                          159.0
# 2591                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 1296                             122.0                             218.0
# 1297                             137.0                             252.0
# 1298                             162.0                             256.0
# 1299                             171.0                             246.0
# 1300                             152.0                             244.0
# ...                                ...                               ...
# 2587                              41.0                              79.0
# 2588                              26.0                              72.0
# 2589                              24.0                              81.0
# 2590                              48.0                              59.0
# 2591                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 1296                             110.0  ...        -0.516062        -0.856551
# 1297                             125.0  ...        -0.530730        -0.847541
# 1298                             115.0  ...        -0.545240        -0.838280
# 1299                             114.0  ...        -0.559589        -0.828770
# 1300                             108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 2587                              31.0  ...         0.687053         0.726608
# 2588                              22.0  ...         0.699458         0.714673
# 2589                              25.0  ...         0.711657         0.702527
# 2590                              21.0  ...         0.723644         0.690173
# 2591                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 1296  -0.866025       -0.5          0.201299          0.979530
# 1297  -0.866025       -0.5          0.394356          0.918958
# 1298  -0.866025       -0.5          0.571268          0.820763
# 1299  -0.866025       -0.5          0.724793          0.688967
# 1300  -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 2587   0.866025        0.5          0.485302         -0.874347
# 2588   0.866025        0.5          0.299363         -0.954139
# 2589   0.866025        0.5          0.101168         -0.994869
# 2590   0.866025        0.5         -0.101168         -0.994869
# 2591   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 1296        -0.974928        -0.222521       2           1
# 1297        -0.781831         0.623490       2           1
# 1298         0.000000         1.000000       2           0
# 1299         0.781831         0.623490       2           0
# 1300         0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 2587         0.781831         0.623490       4           0
# 2588         0.974928        -0.222521       4           0
# 2589         0.433884        -0.900969       4           0
# 2590        -0.433884        -0.900969       4           0
# 2591        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]

# %%
df = df[['collection_date', 'total_patients_hospitalized_covid_confirmed']]
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 1296      01-08-2020                                       5066.0
# 1297      02-08-2020                                       5549.0
# 1298      03-08-2020                                       6100.0
# 1299      04-08-2020                                       5657.0
# 1300      05-08-2020                                       5950.0
# ...              ...                                          ...
# 2587      13-02-2024                                       1509.0
# 2588      14-02-2024                                       1479.0
# 2589      15-02-2024                                       1474.0
# 2590      16-02-2024                                       1508.0
# 2591      17-02-2024                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'item_id'}, axis='columns', inplace=True)
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1823532576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename({'collection_date': 'timestamp', 'total_patients_hospitalized_covid_confirmed': 'item_id'}, axis='columns', inplace=True)
#        timestamp  item_id
# 1296  01-08-2020   5066.0
# 1297  02-08-2020   5549.0
# 1298  03-08-2020   6100.0
# 1299  04-08-2020   5657.0
# 1300  05-08-2020   5950.0
# ...          ...      ...
# 2587  13-02-2024   1509.0
# 2588  14-02-2024   1479.0
# 2589  15-02-2024   1474.0
# 2590  16-02-2024   1508.0
# 2591  17-02-2024   1434.0
#
# [1296 rows x 2 columns]

# %%
df['item_id'] = 'y'
df
# Out:
# C:\Users\aksho\AppData\Local\Temp\ipykernel_21740\1515607402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['item_id'] = 'y'
#        timestamp item_id
# 1296  01-08-2020       y
# 1297  02-08-2020       y
# 1298  03-08-2020       y
# 1299  04-08-2020       y
# 1300  05-08-2020       y
# ...          ...     ...
# 2587  13-02-2024       y
# 2588  14-02-2024       y
# 2589  15-02-2024       y
# 2590  16-02-2024       y
# 2591  17-02-2024       y
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp', 'item_id'], value_name='value')
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, variable, value]
# Index: []

# %%
df.replace({'item_id': {'total_patients_hospitalized_covid_confirmed': 'y'}}, inplace=True)
df
# Out:
#        timestamp  item_id
# 0     01-08-2020   5066.0
# 1     02-08-2020   5549.0
# 2     03-08-2020   6100.0
# 3     04-08-2020   5657.0
# 4     05-08-2020   5950.0
# ...          ...      ...
# 1291  13-02-2024   1509.0
# 1292  14-02-2024   1479.0
# 1293  15-02-2024   1474.0
# 1294  16-02-2024   1508.0
# 1295  17-02-2024   1434.0
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
data.drop("variable", axis='columns', inplace=True)

# %%
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, target]
# Index: []

# %%
data = data.pivot(columns="item_id", index="timestamp", values="target")
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.replace({'item_id': {'total_patients_hospitalized_covid_confirmed': 'y'}}, inplace=True)

# %%
df
# Out:
#        timestamp  item_id
# 0     01-08-2020   5066.0
# 1     02-08-2020   5549.0
# 2     03-08-2020   6100.0
# 3     04-08-2020   5657.0
# 4     05-08-2020   5950.0
# ...          ...      ...
# 1291  13-02-2024   1509.0
# 1292  14-02-2024   1479.0
# 1293  15-02-2024   1474.0
# 1294  16-02-2024   1508.0
# 1295  17-02-2024   1434.0
#
# [1296 rows x 2 columns]

# %%
data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')
data.drop("variable", axis='columns', inplace=True)

# %%
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, target]
# Index: []

# %%
data = df.melt(id_vars=['timestamp', 'item_id'], value_name='target')

# %%
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, variable, target]
# Index: []

# %%
data.drop("variable", axis='columns', inplace=True)

# %%
data
# Out:
# Empty DataFrame
# Columns: [timestamp, item_id, target]
# Index: []

# %%
df = pd.read_csv('CA.csv')

# %%
df = df.drop(columns=df.columns.difference(['collection_date', 'total_patients_hospitalized_covid_confirmed']))

# %%
df
# Out:
#      collection_date  total_patients_hospitalized_covid_confirmed
# 0         01-08-2020                                       5066.0
# 1         02-08-2020                                       5549.0
# 2         03-08-2020                                       6100.0
# 3         04-08-2020                                       5657.0
# 4         05-08-2020                                       5950.0
# ...              ...                                          ...
# 1291      13-02-2024                                       1509.0
# 1292      14-02-2024                                       1479.0
# 1293      15-02-2024                                       1474.0
# 1294      16-02-2024                                       1508.0
# 1295      17-02-2024                                       1434.0
#
# [1296 rows x 2 columns]

# %%
df
# Out:
#       jurisdiction    state collection_date  number_hospitals_reporting_today  \
# 0               AZ  Arizona      01-08-2020                              55.0
# 1               AZ  Arizona      02-08-2020                              76.0
# 2               AZ  Arizona      03-08-2020                              82.0
# 3               AZ  Arizona      04-08-2020                              81.0
# 4               AZ  Arizona      05-08-2020                              84.0
# ...            ...      ...             ...                               ...
# 83606           UT     Utah      13-02-2024                              50.0
# 83607           UT     Utah      14-02-2024                              49.0
# 83608           UT     Utah      15-02-2024                              49.0
# 83609           UT     Utah      16-02-2024                              49.0
# 83610           UT     Utah      17-02-2024                              49.0
#
#        total_hospitals  admissions_all_covid_confirmed  \
# 0                 95.0                            95.0
# 1                 95.0                           124.0
# 2                 95.0                           100.0
# 3                 95.0                           121.0
# 4                 95.0                           120.0
# ...                ...                             ...
# 83606             53.0                            18.0
# 83607             53.0                            22.0
# 83608             53.0                            17.0
# 83609             53.0                             9.0
# 83610             53.0                            13.0
#
#        admissions_70_covid_confirmed  admissions_30_49_covid_confirmed  \
# 0                               26.0                              16.0
# 1                               29.0                              24.0
# 2                               26.0                              21.0
# 3                               32.0                              23.0
# 4                               27.0                              28.0
# ...                              ...                               ...
# 83606                            8.0                               5.0
# 83607                           10.0                               1.0
# 83608                            8.0                               3.0
# 83609                            3.0                               2.0
# 83610                            6.0                               1.0
#
#        admissions_50_69_covid_confirmed  admissions_50_59_covid_confirmed  \
# 0                                  35.0                              16.0
# 1                                  34.0                              12.0
# 2                                  28.0                              14.0
# 3                                  32.0                              12.0
# 4                                  35.0                              14.0
# ...                                 ...                               ...
# 83606                               2.0                               0.0
# 83607                               6.0                               3.0
# 83608                               2.0                               1.0
# 83609                               2.0                               1.0
# 83610                               5.0                               2.0
#
#        ...  day_of_year_sin  day_of_year_cos  month_sin  month_cos  \
# 0      ...        -0.516062        -0.856551  -0.866025       -0.5
# 1      ...        -0.530730        -0.847541  -0.866025       -0.5
# 2      ...        -0.545240        -0.838280  -0.866025       -0.5
# 3      ...        -0.559589        -0.828770  -0.866025       -0.5
# 4      ...        -0.573772        -0.819015  -0.866025       -0.5
# ...    ...              ...              ...        ...        ...
# 83606  ...         0.687053         0.726608   0.866025        0.5
# 83607  ...         0.699458         0.714673   0.866025        0.5
# 83608  ...         0.711657         0.702527   0.866025        0.5
# 83609  ...         0.723644         0.690173   0.866025        0.5
# 83610  ...         0.735417         0.677615   0.866025        0.5
#
#        day_of_month_sin  day_of_month_cos  day_of_week_sin  day_of_week_cos  \
# 0              0.201299          0.979530        -0.974928        -0.222521
# 1              0.394356          0.918958        -0.781831         0.623490
# 2              0.571268          0.820763         0.000000         1.000000
# 3              0.724793          0.688967         0.781831         0.623490
# 4              0.848644          0.528964         0.974928        -0.222521
# ...                 ...               ...              ...              ...
# 83606          0.485302         -0.874347         0.781831         0.623490
# 83607          0.299363         -0.954139         0.974928        -0.222521
# 83608          0.101168         -0.994869         0.433884        -0.900969
# 83609         -0.101168         -0.994869        -0.433884        -0.900969
# 83610         -0.299363         -0.954139        -0.974928        -0.222521
#
#        season  is_weekend
# 0           2           1
# 1           2           1
# 2           2           0
# 3           2           0
# 4           2           0
# ...       ...         ...
# 83606       4           0
# 83607       4           0
# 83608       4           0
# 83609       4           0
# 83610       4           1
#
# [83611 rows x 119 columns]

# %%
import pandas as pd

df = pd.read_csv('imputation_cvd.csv')
df
# Out:
#       jurisdiction    state collection_date  number_hospitals_reporting_today  \
# 0               AZ  Arizona      01-08-2020                              55.0
# 1               AZ  Arizona      02-08-2020                              76.0
# 2               AZ  Arizona      03-08-2020                              82.0
# 3               AZ  Arizona      04-08-2020                              81.0
# 4               AZ  Arizona      05-08-2020                              84.0
# ...            ...      ...             ...                               ...
# 83606           UT     Utah      13-02-2024                              50.0
# 83607           UT     Utah      14-02-2024                              49.0
# 83608           UT     Utah      15-02-2024                              49.0
# 83609           UT     Utah      16-02-2024                              49.0
# 83610           UT     Utah      17-02-2024                              49.0
#
#        total_hospitals  admissions_all_covid_confirmed  \
# 0                 95.0                            95.0
# 1                 95.0                           124.0
# 2                 95.0                           100.0
# 3                 95.0                           121.0
# 4                 95.0                           120.0
# ...                ...                             ...
# 83606             53.0                            18.0
# 83607             53.0                            22.0
# 83608             53.0                            17.0
# 83609             53.0                             9.0
# 83610             53.0                            13.0
#
#        admissions_70_covid_confirmed  admissions_30_49_covid_confirmed  \
# 0                               26.0                              16.0
# 1                               29.0                              24.0
# 2                               26.0                              21.0
# 3                               32.0                              23.0
# 4                               27.0                              28.0
# ...                              ...                               ...
# 83606                            8.0                               5.0
# 83607                           10.0                               1.0
# 83608                            8.0                               3.0
# 83609                            3.0                               2.0
# 83610                            6.0                               1.0
#
#        admissions_50_69_covid_confirmed  admissions_50_59_covid_confirmed  \
# 0                                  35.0                              16.0
# 1                                  34.0                              12.0
# 2                                  28.0                              14.0
# 3                                  32.0                              12.0
# 4                                  35.0                              14.0
# ...                                 ...                               ...
# 83606                               2.0                               0.0
# 83607                               6.0                               3.0
# 83608                               2.0                               1.0
# 83609                               2.0                               1.0
# 83610                               5.0                               2.0
#
#        ...  day_of_year_sin  day_of_year_cos  month_sin  month_cos  \
# 0      ...        -0.516062        -0.856551  -0.866025       -0.5
# 1      ...        -0.530730        -0.847541  -0.866025       -0.5
# 2      ...        -0.545240        -0.838280  -0.866025       -0.5
# 3      ...        -0.559589        -0.828770  -0.866025       -0.5
# 4      ...        -0.573772        -0.819015  -0.866025       -0.5
# ...    ...              ...              ...        ...        ...
# 83606  ...         0.687053         0.726608   0.866025        0.5
# 83607  ...         0.699458         0.714673   0.866025        0.5
# 83608  ...         0.711657         0.702527   0.866025        0.5
# 83609  ...         0.723644         0.690173   0.866025        0.5
# 83610  ...         0.735417         0.677615   0.866025        0.5
#
#        day_of_month_sin  day_of_month_cos  day_of_week_sin  day_of_week_cos  \
# 0              0.201299          0.979530        -0.974928        -0.222521
# 1              0.394356          0.918958        -0.781831         0.623490
# 2              0.571268          0.820763         0.000000         1.000000
# 3              0.724793          0.688967         0.781831         0.623490
# 4              0.848644          0.528964         0.974928        -0.222521
# ...                 ...               ...              ...              ...
# 83606          0.485302         -0.874347         0.781831         0.623490
# 83607          0.299363         -0.954139         0.974928        -0.222521
# 83608          0.101168         -0.994869         0.433884        -0.900969
# 83609         -0.101168         -0.994869        -0.433884        -0.900969
# 83610         -0.299363         -0.954139        -0.974928        -0.222521
#
#        season  is_weekend
# 0           2           1
# 1           2           1
# 2           2           0
# 3           2           0
# 4           2           0
# ...       ...         ...
# 83606       4           0
# 83607       4           0
# 83608       4           0
# 83609       4           0
# 83610       4           1
#
# [83611 rows x 119 columns]

# %%
df = df[df['jurisdiction'] == 'CA']

# %%
df
# Out:
#      jurisdiction       state collection_date  \
# 1296           CA  California      01-08-2020
# 1297           CA  California      02-08-2020
# 1298           CA  California      03-08-2020
# 1299           CA  California      04-08-2020
# 1300           CA  California      05-08-2020
# ...           ...         ...             ...
# 2587           CA  California      13-02-2024
# 2588           CA  California      14-02-2024
# 2589           CA  California      15-02-2024
# 2590           CA  California      16-02-2024
# 2591           CA  California      17-02-2024
#
#       number_hospitals_reporting_today  total_hospitals  \
# 1296                             285.0            371.0
# 1297                             352.0            371.0
# 1298                             355.0            371.0
# 1299                             355.0            371.0
# 1300                             355.0            371.0
# ...                                ...              ...
# 2587                             340.0            371.0
# 2588                             338.0            371.0
# 2589                             335.0            371.0
# 2590                             334.0            371.0
# 2591                             333.0            371.0
#
#       admissions_all_covid_confirmed  admissions_70_covid_confirmed  \
# 1296                           559.0                          156.0
# 1297                           654.0                          193.0
# 1298                           692.0                          215.0
# 1299                           676.0                          208.0
# 1300                           691.0                          224.0
# ...                              ...                            ...
# 2587                           295.0                          155.0
# 2588                           272.0                          140.0
# 2589                           271.0                          143.0
# 2590                           297.0                          159.0
# 2591                           270.0                          155.0
#
#       admissions_30_49_covid_confirmed  admissions_50_69_covid_confirmed  \
# 1296                             122.0                             218.0
# 1297                             137.0                             252.0
# 1298                             162.0                             256.0
# 1299                             171.0                             246.0
# 1300                             152.0                             244.0
# ...                                ...                               ...
# 2587                              41.0                              79.0
# 2588                              26.0                              72.0
# 2589                              24.0                              81.0
# 2590                              48.0                              59.0
# 2591                              27.0                              74.0
#
#       admissions_50_59_covid_confirmed  ...  day_of_year_sin  day_of_year_cos  \
# 1296                             110.0  ...        -0.516062        -0.856551
# 1297                             125.0  ...        -0.530730        -0.847541
# 1298                             115.0  ...        -0.545240        -0.838280
# 1299                             114.0  ...        -0.559589        -0.828770
# 1300                             108.0  ...        -0.573772        -0.819015
# ...                                ...  ...              ...              ...
# 2587                              31.0  ...         0.687053         0.726608
# 2588                              22.0  ...         0.699458         0.714673
# 2589                              25.0  ...         0.711657         0.702527
# 2590                              21.0  ...         0.723644         0.690173
# 2591                              32.0  ...         0.735417         0.677615
#
#       month_sin  month_cos  day_of_month_sin  day_of_month_cos  \
# 1296  -0.866025       -0.5          0.201299          0.979530
# 1297  -0.866025       -0.5          0.394356          0.918958
# 1298  -0.866025       -0.5          0.571268          0.820763
# 1299  -0.866025       -0.5          0.724793          0.688967
# 1300  -0.866025       -0.5          0.848644          0.528964
# ...         ...        ...               ...               ...
# 2587   0.866025        0.5          0.485302         -0.874347
# 2588   0.866025        0.5          0.299363         -0.954139
# 2589   0.866025        0.5          0.101168         -0.994869
# 2590   0.866025        0.5         -0.101168         -0.994869
# 2591   0.866025        0.5         -0.299363         -0.954139
#
#       day_of_week_sin  day_of_week_cos  season  is_weekend
# 1296        -0.974928        -0.222521       2           1
# 1297        -0.781831         0.623490       2           1
# 1298         0.000000         1.000000       2           0
# 1299         0.781831         0.623490       2           0
# 1300         0.974928        -0.222521       2           0
# ...               ...              ...     ...         ...
# 2587         0.781831         0.623490       4           0
# 2588         0.974928        -0.222521       4           0
# 2589         0.433884        -0.900969       4           0
# 2590        -0.433884        -0.900969       4           0
# 2591        -0.974928        -0.222521       4           1
#
# [1296 rows x 119 columns]
